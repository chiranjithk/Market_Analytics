# %%
# Databricks notebook source
# -----------------------------------------------------------------------------
# Shared config. Run with %run "../common/config" from every ingestion notebook.
# -----------------------------------------------------------------------------

CATALOG = "stock_market"
BRONZE = f"{CATALOG}.bronze"
SILVER = f"{CATALOG}.silver"
GOLD = f"{CATALOG}.gold"

MASTERS_VOLUME = f"/Volumes/{CATALOG}/bronze/market_landing"
WATERMARK_TABLE = f"{BRONZE}.ingestion_watermark"

MFAPI_BASE_URL = "https://api.mfapi.in/mf"

# yfinance / mfapi batching — tune these if you hit rate limits
YF_BATCH_SIZE = 150
MFAPI_BATCH_SIZE = 150
MFAPI_MAX_WORKERS = 8

DEFAULT_BACKFILL_START = "2005-01-01"
